# %%
# !pip install librosa
# Out:
# ...
#      |████████████████████████████████| 183 kB 1.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 377 kB 4.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 323 kB 7.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.2 MB 8.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 613 kB 12.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 47 kB 9.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 18.4 MB 3.6 MB/s eta 0:00:01    |█████████▎                      | 5.3 MB 2.4 MB/s eta 0:00:06
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...
#   Created wheel for librosa: filename=librosa-0.8.0-py3-none-any.whl size=201376 sha256=2b7d059d3b44d476fd0ad4da33b37cd92c68159efd3649834bdfc5de6a1152d1
#   Stored in directory: /Users/aravind/Library/Caches/pip/wheels/aa/5a/92/d52f6f8560ff05a2525e6030a1903412df876714241fb76802
# ...

# %%
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import ShortTermFeatures
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
sampling_rate, signal = audioBasicIO.read_audio_file("/Volumes/Macintosh HD - Data/Users/admin/Documents/HD Drive/DataProjects_Data/DepressionData/303.wav")

# %%
signal
# Out:
# array([ 2,  0, -2, ..., -1,  0,  0], dtype=int16)

# %%
sampling_rate
# Out:
# 16000

# %%
len(signal)
# Out:
# 15179512

# %%
signal.shape
# Out:
# (15179512,)

# %%
Pxx, freqs, bins, im = plt.specgram(signal,Fs=sampling_rate,NFFT=256)
print(Pxx.shape)
# Out:
# (129, 118588)

# %%
plt.plot(Pxx)
# Out:
# ...
#  ...]

# %%
plt.imshow(Pxx)
plt.xlim(0,500)
# Out:
# (0.0, 500.0)

# %%
specgram, f_axis, time_axis = ShortTermFeatures.spectrogram(signal, sampling_rate, 0.050 * sampling_rate, 0.025 * sampling_rate)
# Out:
# (37946, 400)

# %%
fig = plt.figure()
plt.imshow(specgram.T)
plt.xlim(10000,11000)
# Out:
# (10000.0, 11000.0)
